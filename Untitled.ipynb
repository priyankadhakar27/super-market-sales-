# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data/SuperMarket Analysis.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#           Time      Payment    cogs  gross margin percentage  gross income  \
# 0   1:08:00 PM      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
## cleaning the data

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Sales                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.head()
# Out:
#   Branch       City  Gender  Unit price  Quantity     Sales       Date  \
# 0   Alex     Yangon  Female       74.69         7  548.9715   1/5/2019
# 1   Giza  Naypyitaw  Female       15.28         5   80.2200   3/8/2019
# 2   Alex     Yangon  Female       46.33         7  340.5255   3/3/2019
# 3   Alex     Yangon  Female       58.22         8  489.0480  1/27/2019
# 4   Alex     Yangon  Female       86.31         7  634.3785   2/8/2019
#
#           Time  Rating
# 0   1:08:00 PM     9.1
# 1  10:29:00 AM     9.6
# 2   1:23:00 PM     7.4
# 3   8:33:00 PM     8.4
# 4  10:37:00 AM     5.3

# %%
df.isnull().sum()
# Out:
# Branch        0
# City          0
# Gender        0
# Unit price    0
# Quantity      0
# Sales         0
# Date          0
# Time          0
# Rating        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Branch      1000 non-null   str
#  1   City        1000 non-null   str
#  2   Gender      1000 non-null   str
#  3   Unit price  1000 non-null   float64
#  4   Quantity    1000 non-null   int64
#  5   Sales       1000 non-null   float64
#  6   Date        1000 non-null   str
#  7   Time        1000 non-null   str
#  8   Rating      1000 non-null   float64
# dtypes: float64(3), int64(1), str(5)
# memory usage: 70.4 KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.describe()
# Out:
#         Unit price     Quantity        Sales                        Date  \
# count  1000.000000  1000.000000  1000.000000                        1000
# mean     55.672130     5.510000   322.966749  2019-02-14 00:05:45.600000
# min      10.080000     1.000000    10.678500         2019-01-01 00:00:00
# 25%      32.875000     3.000000   124.422375         2019-01-24 00:00:00
# 50%      55.230000     5.000000   253.848000         2019-02-13 00:00:00
# 75%      77.935000     8.000000   471.350250         2019-03-08 00:00:00
# max      99.960000    10.000000  1042.650000         2019-03-30 00:00:00
# std      26.494628     2.923431   245.885335                         NaN
#
#            Rating
# count  1000.00000
# mean      6.97270
# min       4.00000
# 25%       5.50000
# 50%       7.00000
# 75%       8.50000
# max      10.00000
# std       1.71858

# %%
## EDA

# %%
df.groupby('Quantity')['Sales'].sum()
# Out:
# Quantity
# 1      6442.3485
# 2     10994.8020
# 3     16081.6950
# 4     25247.9220
# 5     27051.4125
# 6     34455.2040
# 7     43664.6595
# 8     40316.3040
# 9     48783.4515
# 10    69928.9500
# Name: Sales, dtype: float64

# %%
df=df[["Branch",
      
       "City",
        "Customer type",
       "Gender",
       "Product line"
       ,"Unit price","Quantity","Sales","Date","Time","Rating"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df=df[["Branch",
#       2
#       3        "City",
#       4         "Customer type",
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...
